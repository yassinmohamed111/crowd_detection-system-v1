# %% [raw]
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="m3xSznjFg3CWq78xi1BS")
project = rf.workspace("gp-33org").project("crowd-detetction")
version = project.version(2)
dataset = version.download("yolov8")

# %%
import yaml

# Path to the data.yaml file
data_yaml_path = '/kaggle/working/crowd-detect-3/data.yaml'

# Read the content of the data.yaml file
with open(data_yaml_path, 'r') as file:
    data = yaml.safe_load(file)

# Modify the data as needed
data['train'] = '/kaggle/working/crowd-detect-3/train'
data['val'] = '/kaggle/working/crowd-detect-3/valid'
data['test'] = '/kaggle/working/crowd-detect-3/test'

# Write the modified data back to the data.yaml file
with open(data_yaml_path, 'w') as file:
    yaml.dump(data, file)

# %%
import torch

model = YOLO("yolov8l")
model.train(data="/kaggle/working/crowd-detect-3/data.yaml", epochs=100 , device =[0,1])
